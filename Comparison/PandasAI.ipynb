# %%
import os
path_to_folder = r'C:\Users\abhij\Desktop\CV_Project\EDA ChatBot'
path_to_config = os.path.join(path_to_folder,'config.ini')
os.chdir(path_to_folder)

# %%
import configparser
import pandas as pd

# To call LLMs
from langchain_groq import ChatGroq
from pandasai import SmartDataframe

# %% [markdown]
# ### Step 1: Read the config file

# %%
config = configparser.ConfigParser()
config.read(path_to_config)
# Out:
# ['C:\\Users\\abhij\\Desktop\\CV_Project\\EDA ChatBot\\config.ini']

# %% [markdown]
# ### Step 2: Calling the LLM

# %%
llm = ChatGroq(
    model=config['LLM']['model'],
    api_key=config['LLM']['api_key'],
    temperature=float(config['LLM']['temperature'])
)

# %% [markdown]
# ### Step 3: Reading the input data

# %%
data1= pd.read_csv(r'C:\Users\abhij\Desktop\LangChain\LLama-recipes\Querying Pandas DataFrame\titanic.csv')

# %% [markdown]
# ### Step 4: Calling and Defining the `SmartDataframe` for using `PandasAI`

# %%
# Initializing an instance of PandasAI with OpenAI environment
sdf = SmartDataframe(data1, config={"llm": llm})

# %% [markdown]
# ----
# ## Conversation Begins !

# %%
#Create the prompt variable
question = "Hi"
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# C:/Users/abhij/Desktop/CV_Project/EDA ChatBot/exports/charts/temp_chart.png
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# C:/Users/abhij/Desktop/CV_Project/EDA ChatBot/exports/charts/temp_chart.png
# Traceback (most recent call last):
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nNo result returned\n'

# %%
#Create the prompt variable
question = "What's the shape of the data, and provide overview about the columns?"
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# {'type': 'string', 'value': "The shape of the data is (891, 12). The columns are: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']."}
# "The shape of the data is (891, 12). The columns are: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']."

# %%
#Create the prompt variable
question = "What's the survival rate for different categories ?"
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# Traceback (most recent call last):
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 96, in execute
#     if not OutputValidator.validate_result(result):
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\helpers\output_validator.py", line 73, in validate_result
#     raise InvalidOutputValueMismatch(
# pandasai.exceptions.InvalidOutputValueMismatch: Result must be in the format of dictionary of type and value
# 'Unfortunately, I was not able to answer your question, because of the following error:\n\nResult must be in the format of dictionary of type and value\n'

# %%
#Create the prompt variable
question ="Please identify the numeric column in the dataframe, and tell if they are right skewed or left skewed."
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# "Skewness of numeric columns: {'PassengerId': 'normally distributed', 'Survived': 'right skewed', 'Pclass': 'left skewed', 'Age': 'right skewed', 'SibSp': 'right skewed', 'Parch': 'right skewed', 'Fare': 'right skewed'}"

# %%
#Create the prompt variable
question ="Does sex and PClass have any effect on Survival of a passenger?"
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# Survival Rate by Sex:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
#
# Survival Rate by Pclass:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
# Traceback (most recent call last):
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 171, in execute_code
#     exec(code, environment)
#   File "<string>", line 21
# SyntaxError: 'return' outside function
# "Unfortunately, I was not able to answer your question, because of the following error:\n\n'return' outside function (<string>, line 21)\n"

# %%
#Create the prompt variable
question ="Identify the pairs of closely correlated features."
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# <string>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# 'Closely correlated features: []'

# %%
#Create the prompt variable
question ="What's the most common last name for the Passengers?"
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# 'The most common last name is Andersson.'

# %%
#Create the prompt variable
question = "Analyze the survival rate of passengers based on their class and gender, then create a new feature that combines age groups with these factors, and finally visualize the results."
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
#    Pclass     Sex  Survived
# 0       1  female  0.968085
# 1       1    male  0.368852
# 2       2  female  0.921053
# 3       2    male  0.157407
# 4       3  female  0.500000
# 5       3    male  0.135447
#    Pclass     Sex  Survived
# 0       1  female  0.968085
# 1       1    male  0.368852
# 2       2  female  0.921053
# 3       2    male  0.157407
# 4       3  female  0.500000
# 5       3    male  0.135447
#    Pclass     Sex  Survived
# 0       1  female  0.968085
# 1       1    male  0.368852
# 2       2  female  0.921053
# 3       2    male  0.157407
# 4       3  female  0.500000
# 5       3    male  0.135447
#    Pclass     Sex  Survived
# 0       1  female  0.968085
# 1       1    male  0.368852
# 2       2  female  0.921053
# 3       2    male  0.157407
# 4       3  female  0.500000
# 5       3    male  0.135447
# Traceback (most recent call last):
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 97, in execute
#     raise InvalidOutputValueMismatch(
# pandasai.exceptions.InvalidOutputValueMismatch: Value type <class 'module'> must match with type plot
# "Unfortunately, I was not able to answer your question, because of the following error:\n\nValue type <class 'module'> must match with type plot\n"

# %%
#Create the prompt variable
question = "Just to check, if you remember the information or not. What was the shape of the input data provided?"
#Pass the prompt variable as parameter to the sdf instance function
sdf.chat(question)
# Out:
# Traceback (most recent call last):
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "C:\Users\abhij\Desktop\LangChain\langchain_env\lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 171, in execute_code
#     exec(code, environment)
#   File "<string>", line 5, in <module>
# NameError: name 'sns' is not defined
# "Unfortunately, I was not able to answer your question, because of the following error:\n\nname 'sns' is not defined\n"

# %% [markdown]
# -------------
